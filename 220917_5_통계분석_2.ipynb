# %%
# 다중공선성
# 독립변수들간의 강한 상관관계를 나타낸다.
# A,B의 변수가 비슷한 변수, 누가 주로 영향을 미치는지 모른다.
# 분산팽창요인(VIF) 10 이상이면 심각

# %%
import pandas as pd

Cars = pd.read_csv('data/Cars93.csv')
Cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
Cars[['EngineSize','RPM', 'Weight', 'Length']]
# Out:
#     EngineSize   RPM  Weight  Length
# 0          1.8  6300    2705     177
# 1          3.2  5500    3560     195
# 2          2.8  5500    3375     180
# 3          2.8  5500    3405     193
# 4          3.5  5700    3640     186
# ..         ...   ...     ...     ...
# 88         2.5  4500    3960     187
# 89         2.0  5800    2985     180
# 90         2.8  5800    2810     159
# 91         2.3  5400    2985     190
# 92         2.4  6200    3245     184
#
# [93 rows x 4 columns]

# %%
# 의심?
# Length가 높으면 Weight가 높은가?
# EngineSize가 높으면 Wegiht가 높은가?
Cars[['EngineSize','RPM', 'Weight', 'Length']].corr()
# Out:
#             EngineSize       RPM    Weight    Length
# EngineSize    1.000000 -0.547898  0.845075  0.780283
# RPM          -0.547898  1.000000 -0.427931 -0.441249
# Weight        0.845075 -0.427931  1.000000  0.806274
# Length        0.780283 -0.441249  0.806274  1.000000

# %%
pip install statsmodels
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 41.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.7/233.7 kB 8.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# EngineSize와 Weight가 0.9는 아니지만 강한 양의 상관관계
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

model = smf.ols(formula = 'Price ~ EngineSize + RPM + Weight + Length', data = Cars)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     28.34
# Date:                Sat, 17 Sep 2022   Prob (F-statistic):           3.93e-15
# Time:                        16:14:59   Log-Likelihood:                -303.89
# No. Observations:                  93   AIC:                             617.8
# Df Residuals:                      88   BIC:                             630.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -45.4934     14.654     -3.104      0.003     -74.616     -16.371
# ...

# %%
# VIF 진행
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
Y, X = dmatrices('Price ~ EngineSize + RPM + Weight + Length', data = Cars, return_type = 'dataframe')

# %%
Y
# Out:
#     Price
# 0    15.9
# 1    33.9
# 2    29.1
# 3    37.7
# 4    30.0
# ..    ...
# 88   19.7
# 89   20.0
# 90   23.3
# 91   22.7
# 92   26.7
#
# [93 rows x 1 columns]

# %%
X
# Out:
#     Intercept  EngineSize     RPM  Weight  Length
# 0         1.0         1.8  6300.0  2705.0   177.0
# 1         1.0         3.2  5500.0  3560.0   195.0
# 2         1.0         2.8  5500.0  3375.0   180.0
# 3         1.0         2.8  5500.0  3405.0   193.0
# 4         1.0         3.5  5700.0  3640.0   186.0
# ..        ...         ...     ...     ...     ...
# 88        1.0         2.5  4500.0  3960.0   187.0
# 89        1.0         2.0  5800.0  2985.0   180.0
# 90        1.0         2.8  5800.0  2810.0   159.0
# 91        1.0         2.3  5400.0  2985.0   190.0
# 92        1.0         2.4  6200.0  3245.0   184.0
#
# [93 rows x 5 columns]

# %%
# EngineSize(1), RPM(2), Weight(3), Length(4)
variance_inflation_factor(X.values, 1)
# Out:
# 4.427251654464432

# %%
var_list = []
for i in range(1, len(X.columns)):
   var_list.append([variance_inflation_factor(X.values, i), X.columns[i]])
    
var_list
# Out:
# [[4.427251654464432, 'EngineSize'],
#  [1.4444465912486613, 'RPM'],
#  [4.378638493452148, 'Weight'],
#  [3.1822925492065623, 'Length']]

# %%
pd.DataFrame(var_list, columns =['vlf', 'columns'])
# 모두 삭제할 정도의 VIF의 값乙 가지고 있지 않다.
# Out:
#         vlf     columns
# 0  4.427252  EngineSize
# 1  1.444447         RPM
# 2  4.378638      Weight
# 3  3.182293      Length

# %%
# 변수선택법
# 트렌드 X -> L2.penalty 기법 많이 사용
# 회귀분석시 반드시 변수선택법을 사용하는 것이 아닌, 문제로 나올 경우에만 사용
# R은 내장함수 존재, python은 직접 함수 작성 필요

# %%
# F통계량은 높을 수록 모델 유의, AIC은 낮을 수록 모델의 성능이 좋다.
# L(LikeHood) 값이 높을 수록 모델이 적합하다.
# K : 모형에 추정된 파라미터 개수

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

model = smf.ols(formula = 'Price ~ EngineSize + RPM + Weight + Length', data = Cars)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     28.34
# Date:                Sat, 17 Sep 2022   Prob (F-statistic):           3.93e-15
# Time:                        16:37:08   Log-Likelihood:                -303.89
# No. Observations:                  93   AIC:                             617.8
# Df Residuals:                      88   BIC:                             630.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -45.4934     14.654     -3.104      0.003     -74.616     -16.371
# ...

# %%
# Length 제거 후 
# AIC(617.8 -> 616.1)
# Weight : 0.002 -> 0.001
# 즉, 한 변수를 제거하면 다른 변수도 영향을 받는다.
# 삭제 또는 추가하는 조합으로 최적의 변수를 찾는다.
model = smf.ols(formula = 'Price ~ EngineSize + RPM + Weight', data = Cars)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.547
# Method:                 Least Squares   F-statistic:                     37.98
# Date:                Sat, 17 Sep 2022   Prob (F-statistic):           6.75e-16
# Time:                        16:43:39   Log-Likelihood:                -304.05
# No. Observations:                  93   AIC:                             616.1
# Df Residuals:                      89   BIC:                             626.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -51.7933      9.106     -5.688      0.000     -69.887     -33.699
# ...

# %%
import time
import itertools

# %%
def processSubset(X,y, feature_set):
            model = sm.OLS(y,X[list(feature_set)]) # Modeling
            regr = model.fit() # 모델 학습
            AIC = regr.aic # 모델의 AIC
            return {"model":regr, "AIC":AIC}
        
'''
전진선택법
'''
def forward(X, y, predictors):
    
    # 데이터 변수들이 미리정의된 predictors에 있는지 없는지 확인 및 분류
    remaining_predictors = [p for p in X.columns.difference(['Intercept']) if p not in predictors]
    results = []
    for p in remaining_predictors:
        results.append(processSubset(X=X, y= y, feature_set=predictors+[p]+['Intercept']))
        
    # 데이터프레임으로 변환
    models = pd.DataFrame(results)

    # AIC가 가장 낮은 것을 선택
    best_model = models.loc[models['AIC'].argmin()] # index

    print("Processed ", models.shape[0], "models on", len(predictors)+1, "predictors in")
    print('Selected predictors:',best_model['model'].model.exog_names,' AIC:',best_model[0] )
    return best_model

'''
후진소거법
'''
def backward(X,y,predictors):
    tic = time.time()
    results = []
    
    # 데이터 변수들이 미리정의된 predictors 조합 확인
    for combo in itertools.combinations(predictors, len(predictors) - 1):
        results.append(processSubset(X=X, y= y,feature_set=list(combo)+['Intercept']))
    models = pd.DataFrame(results)
    
    # 가장 낮은 AIC를 가진 모델을 선택
    best_model = models.loc[models['AIC'].argmin()]
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors) - 1, "predictors in",
          (toc - tic))
    print('Selected predictors:',best_model['model'].model.exog_names,' AIC:',best_model[0] )
    return best_model



'''
단계적 선택법(중점)
'''

def Stepwise_model(X,y):
    Stepmodels = pd.DataFrame(columns=["AIC", "model"])
    tic = time.time()
    predictors = []
    Smodel_before = processSubset(X,y,predictors+['Intercept'])['AIC']
    # 변수 1~10개 : 0~9 -> 1~10
    for i in range(1, len(X.columns.difference(['Intercept'])) + 1):
        Forward_result = forward(X=X, y=y, predictors=predictors) # constant added
        print('forward')
        Stepmodels.loc[i] = Forward_result
        predictors = Stepmodels.loc[i]["model"].model.exog_names
        predictors = [ k for k in predictors if k != 'Intercept']
        Backward_result = backward(X=X, y=y, predictors=predictors)
        if Backward_result['AIC']< Forward_result['AIC']:
            Stepmodels.loc[i] = Backward_result
            predictors = Stepmodels.loc[i]["model"].model.exog_names
            Smodel_before = Stepmodels.loc[i]["AIC"]
            predictors = [ k for k in predictors if k != 'Intercept']
            print('backward')
        if Stepmodels.loc[i]['AIC']> Smodel_before:
            break
        else:
            Smodel_before = Stepmodels.loc[i]["AIC"]
    toc = time.time()
    print("Total elapsed time:", (toc - tic), "seconds.")
    return (Stepmodels['model'][len(Stepmodels['model'])])

# %%
from patsy import dmatrices
y, X = dmatrices('Price ~ EngineSize + RPM + Weight + Length', data = Cars, return_type = 'dataframe' )

# %%
Stepwise_best_model = Stepwise_model(X=X, y=y)
# Out:
# Processed  4 models on 1 predictors in
# Selected predictors: ['Weight', 'Intercept']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x28eb7a200>
# forward
# Processed  1 models on 0 predictors in 0.0009920597076416016
# Selected predictors: ['Intercept']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x114f26f80>
# Processed  3 models on 2 predictors in
# Selected predictors: ['Weight', 'RPM', 'Intercept']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x28eb7abc0>
# forward
# Processed  2 models on 1 predictors in 0.0012202262878417969
# Selected predictors: ['Weight', 'Intercept']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x28eb7aa40>
# Processed  2 models on 3 predictors in
# Selected predictors: ['Weight', 'RPM', 'EngineSize', 'Intercept']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x28eb7a230>
# forward
# ...

# %%
Stepwise_best_model.aic
# Out:
# 616.0976497740975

# %%
Stepwise_best_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.547
# Method:                 Least Squares   F-statistic:                     37.98
# Date:                Sat, 17 Sep 2022   Prob (F-statistic):           6.75e-16
# Time:                        16:55:32   Log-Likelihood:                -304.05
# No. Observations:                  93   AIC:                             616.1
# Df Residuals:                      89   BIC:                             626.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Weight         0.0073      0.002      3.372      0.001       0.003       0.012
# ...
